# %% [markdown]
# # Data Analysis 2

# %%
print("Q_1_ANS :- ")
# Out:
# Q_1_ANS :-

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('flight_price.xlsx')

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# ## There are 10683 rows and 11 columns in the dataset

# %%
print("Q_2_ANS :- ")
# Out:
# Q_2_ANS :-

# %%
sns.histplot( data = df['Price'],bins=30,kde = True )
plt.xlabel('Flight Prices')
plt.ylabel('Frequency')
plt.title('Distribution of Flight Prices')
# Out:
# Text(0.5, 1.0, 'Distribution of Flight Prices')

# %%
print("Q_3_ANS :- ")
# Out:
# Q_3_ANS :-

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [markdown]
# ## the minimum price is 1759 and maximum price is 79512

# %%
print("Q_4_ANS :- ")
# Out:
# Q_4_ANS :-

# %%
sns.boxplot(data = df,x = df['Airline'] , y = df['Price'])
# Out:
# <Axes: xlabel='Airline', ylabel='Price'>

# %%
print("Q_5_ANS :- ")
# Out:
# Q_5_ANS :-

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
print("Q_6_ANS :- To identify the peak travel season from the Flight Price dataset, there are several features you can analyze. Here are some key factors to consider:\n\n1. Date/Time: Analyze the flight prices over different months, seasons, or specific time periods to identify any patterns or trends. Look for months or seasons when flight prices tend to be consistently higher or lower.\n\n2. Demand: Evaluate the demand for flights during different periods. This can be measured by analyzing the number of bookings, passenger volume, or any other relevant indicators. Higher demand typically corresponds to peak travel seasons.\n\n3. Holidays and Events: Consider the occurrence of holidays, festivals, or major events that attract travelers. Analyze flight prices during these periods to see if there are significant price fluctuations.\n\n4. Destination: Explore flight prices to specific destinations and check if there are any particular times when prices spike due to popular events, weather conditions, or tourist seasons.\n\nOnce you have analyzed these features and identified the peak travel season, you can present your findings to your boss. Here's a suggested approach for presenting your analysis:\n\n1. Summary: Begin with a concise summary of your findings, stating the identified peak travel season and any notable trends or patterns you observed.\n\n2. Visualizations: Utilize visualizations such as line graphs, bar charts, or heatmaps to illustrate the fluctuations in flight prices over time, highlighting the peak season. Include labels and annotations to make the visualizations clear and easy to interpret.\n\n3. Supporting Data: Provide supporting data, such as average flight prices or percentage variations during the peak season compared to other periods. Include statistics and figures to strengthen your analysis.\n\n4. Key Factors: Explain the key factors you considered in determining the peak travel season, such as demand, holidays/events, or destination-specific trends. Highlight the relevance of these factors in driving the fluctuations in flight prices.\n\n5. Recommendations: Offer recommendations based on your analysis. For example, suggest marketing strategies or promotions to capitalize on the peak travel season, optimize pricing strategies during off-peak seasons, or identify potential partnerships or collaborations with airlines or hotels.\n\n6. Limitations: Mention any limitations of your analysis, such as data availability, potential biases, or factors that might have influenced the results. This demonstrates transparency and ensures a comprehensive understanding of the analysis.\n\n7. Conclusion: Conclude your presentation by summarizing the key findings, emphasizing the identified peak travel season, and reiterating the proposed actions or recommendations based on the analysis.\n\nBy following this approach, you can effectively communicate your analysis of the Flight Price dataset and provide your boss with valuable insights to make informed decisions regarding the peak travel season and related business strategies.\n\n ")
# Out:
# Q_6_ANS :- To identify the peak travel season from the Flight Price dataset, there are several features you can analyze. Here are some key factors to consider:
#
# 1. Date/Time: Analyze the flight prices over different months, seasons, or specific time periods to identify any patterns or trends. Look for months or seasons when flight prices tend to be consistently higher or lower.
#
# 2. Demand: Evaluate the demand for flights during different periods. This can be measured by analyzing the number of bookings, passenger volume, or any other relevant indicators. Higher demand typically corresponds to peak travel seasons.
#
# 3. Holidays and Events: Consider the occurrence of holidays, festivals, or major events that attract travelers. Analyze flight prices during these periods to see if there are significant price fluctuations.
#
# ...

# %%
print("Q_7_ANS :- Date/Time: Analyze flight prices over time to identify any seasonal or long-term trends. Break down the data by month, quarter, or year to observe patterns in price fluctuations.\n\nRoute/Location: Explore flight prices for different routes or specific locations to identify any consistent trends or differences in pricing. Analyze popular routes and compare them to less-traveled routes.\n\nAirlines: Investigate flight prices offered by different airlines to identify variations in pricing strategies. Compare the average prices, price ranges, or discounts provided by different airlines to identify any trends or preferences.\n\nDuration: Examine the relationship between flight duration and prices. Determine if there is a correlation between longer or shorter flights and corresponding price differences.\n\nAdvanced Booking: Analyze how flight prices change based on the lead time before the departure date. Determine if there are any patterns or trends that indicate the optimal time to book a flight for the best price. ")
# Out:
# Q_7_ANS :- Date/Time: Analyze flight prices over time to identify any seasonal or long-term trends. Break down the data by month, quarter, or year to observe patterns in price fluctuations.
#
# Route/Location: Explore flight prices for different routes or specific locations to identify any consistent trends or differences in pricing. Analyze popular routes and compare them to less-traveled routes.
#
# Airlines: Investigate flight prices offered by different airlines to identify variations in pricing strategies. Compare the average prices, price ranges, or discounts provided by different airlines to identify any trends or preferences.
#
# Duration: Examine the relationship between flight duration and prices. Determine if there is a correlation between longer or shorter flights and corresponding price differences.
#
# ...

# %%
category = pd.DataFrame(df['Route'].value_counts())        
category.rename(columns = {'Route':'Count'},inplace=True)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=category.index[:10], y ='Count',data = category[:10],palette='hls')
plt.title('Top 10 Routes')
plt.xticks(rotation=90)
plt.show()

# %%
print("Q_8_ANS :- ")
# Out:
# Q_8_ANS :-

# %%
sns.barplot(data = df,x = df['Route'][:10] , y = df['Price'],palette='hls')
# Out:
# <Axes: xlabel='Route', ylabel='Price'>

# %%
sns.barplot(data = df,x = df['Duration'][:10] , y = df['Price'],palette='hls')
# Out:
# <Axes: xlabel='Duration', ylabel='Price'>

# %%
sns.barplot(data = df,x = df['Total_Stops'][:10] , y = df['Price'],palette='hls')
# Out:
# <Axes: xlabel='Total_Stops', ylabel='Price'>

# %%
sns.barplot(data = df,x = df['month'][:10] , y = df['Price'],palette='hls')
# Out:
# <Axes: xlabel='month', ylabel='Price'>

# %% [markdown]
# # Observations
#
# ### Route feature affect flight prices and also month affect the price also Duration , Total_Stops , days this feature can affect the flight prices and all the feature affect on flights prices.

# %% [markdown]
# # PlayStore

# %%
print("Q_9_ANS :- ")
# Out:
# Q_9_ANS :-

# %%
df1 = pd.read_csv('google_playsotr.csv')

# %%
df1.shape
# Out:
# (10841, 14)

# %% [markdown]
# ## Observations
# ### google play dataset have 10841 rows and 14 columns.

# %%
print("Q_10_ANS :- ")
# Out:
# Q_10_ANS :-

# %%
sns.boxplot(data = df1 , x = df1['Category'] , y = df1['Rating'])
# Out:
# <Axes: xlabel='Category', ylabel='Rating'>

# %% [markdown]
# ## Observations
# ### the rating of apps vary by category in this dataset.

# %%
print("Q_11_ANS :- ")
# Out:
# Q_11_ANS :-

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0           0
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ## Observations
# ### In this dataset have 1474 missing values in Rating feature and Type , Countent Rating features have 1 missing value and Current ver feature have 8 missing values and also android ver have 3 missing values.
# ### this missing values has affect to train machine learning model.

# %%
print("Q_12_ANS :- ")
# Out:
# Q_12_ANS :-

# %%
sns.scatterplot(data = df1 , x = df1['Size'][:50] , y = df1['Rating'][:50])
plt.title('Relationship between Size and Rating')
# Out:
# Text(0.5, 1.0, 'Relationship between Size and Rating')

# %% [markdown]
# ## Observations
# ### There are No Relationship between Size of an App and Rating of an App in this dataset.

# %%
print("Q_13_ANS :- ")
# Out:
# Q_13_ANS :-

# %%
chars_to_remove=['+',',','$']
cols_to_clean=['Installs','Price']
for item in chars_to_remove:
    for cols in cols_to_clean:
        df1[cols]=df1[cols].str.replace(item,'')

# %%
df1['Installs']=df1['Installs'].astype('int')
df1['Price']=df1['Price'].astype('float')

# %%
plt.figure(figsize = (15,8))
sns.barplot(data = df1 , x = df1['Category'], y = df1['Price'])
plt.xlabel('App Type')
plt.ylabel('Average Price ($)')
plt.title('Average Prices by App Type')
# Out:
# Text(0.5, 1.0, 'Average Prices by App Type')

# %% [markdown]
# ## Observation
# ### The strong relationship between types of app and is prices of this app.
# ### Category is affect to the prices of the app. and highly coreated with prices.

# %%
print("Q_14_ANS :- ")
# Out:
# Q_14_ANS :-

# %%
plt.figure(figsize=(15,6))
sns.barplot(data =df1,x= df1['Category'], y = df1['Installs'],palette='hls')
plt.title('App categories')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Observation
# ### this Categories of large numbers of installs in the playstore.
# ### Communication Category App is large number of installs into playstore.

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=category.index[:10], y ='Count',data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Observation
# ### this Top 10 Categories of large numbers of installs in the playstore.
# ### Family Category App is large number of Count into playstore.

# %%
print("Q_15_ANS :- ")
# Out:
# Q_15_ANS :-

# %%
category = pd.DataFrame(df1['Category'].value_counts())  
category.rename(columns = {'Category':'Count'},inplace=True)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=category.index[:10], y ='Count',data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(data = df1 , x = df1['Category'] , y = df1['Rating'])
# Out:
# <Axes: xlabel='Category', ylabel='Rating'>

# %% [markdown]
# ## Observation
# ### I am analysis this features Category and Rating and Count
# ### The Top 10 App Categories has installs into google playsotre.
# ### Its my analysis i would suggest you can built specific app into Top 10 Categories App.
# ### I have recommended you can make Family Category App.

# %%
print("Q_16_ANS :- ")
# Out:
# Q_16_ANS :-

# %%
plt.figure(figsize=(15,6))
sns.barplot(data =df1,x= df1['Category'], y = df1['Installs'],palette='hls')
plt.title('App categories')
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(data = df1 , x = df1['Category'] , y = df1['Rating'])
# Out:
# <Axes: xlabel='Category', ylabel='Rating'>

# %% [markdown]
# ## Observation
# ### Its my analysis features Category and Installs and Rating this fratures to predect results.
# ### The App Categories has installs into google playsotre.
# ### Its my analysis i would suggest you can built specific app into Categories App.
# ### I have recommended you can make Communication Category App.

# %%
print("Q_17_ANS :- ")
# Out:
# Q_17_ANS :-

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x=category.index[:10], y ='Count',data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(data = df1 , x = df1['Category'] , y = df1['Rating'])
# Out:
# <Axes: xlabel='Category', ylabel='Rating'>

# %%
# pip install matplotlib==3.6.0 --force-reinstall
